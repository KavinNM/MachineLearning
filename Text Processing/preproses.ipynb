# %%
import re
import string
import time
from copy import deepcopy

# %%
import pandas as pd

# %%
df= pd.read_csv('test.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of                                                    text  label
# 0     im feeling rather rotten so im not very ambiti...      0
# 1             im updating my blog because i feel shitty      0
# 2     i never make her separate from me because i do...      0
# 3     i left with my bouquet of red and yellow tulip...      1
# 4       i was feeling a little vain when i did this one      0
# ...                                                 ...    ...
# 1995  i just keep feeling like someone is being unki...      3
# 1996  im feeling a little cranky negative after this...      3
# 1997  i feel that i am useful to my people and that ...      1
# 1998  im feeling more comfortable with derby i feel ...      1
# 1999  i feel all weird when i have to meet w people ...      4
#
# [2000 rows x 2 columns]>

# %%
df=df.drop(['label'],axis=1)

# %%
df
# Out:
#                                                    text
# 0     im feeling rather rotten so im not very ambiti...
# 1             im updating my blog because i feel shitty
# 2     i never make her separate from me because i do...
# 3     i left with my bouquet of red and yellow tulip...
# 4       i was feeling a little vain when i did this one
# ...                                                 ...
# 1995  i just keep feeling like someone is being unki...
# 1996  im feeling a little cranky negative after this...
# 1997  i feel that i am useful to my people and that ...
# 1998  im feeling more comfortable with derby i feel ...
# 1999  i feel all weird when i have to meet w people ...
#
# [2000 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2000 non-null   object
# dtypes: object(1)
# memory usage: 15.8+ KB

# %%
pip install ekphrasis
# Out:
# Requirement already satisfied: ekphrasis in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (0.5.4)
# Requirement already satisfied: termcolor in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ekphrasis) (2.4.0)
# Requirement already satisfied: tqdm in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ekphrasis) (4.66.2)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python312\site-packages (from ekphrasis) (0.4.6)
# Requirement already satisfied: ujson in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ekphrasis) (5.9.0)
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ekphrasis) (3.8.3)
# Requirement already satisfied: nltk in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ekphrasis) (3.8.1)
# Requirement already satisfied: ftfy in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ekphrasis) (6.2.0)
# Requirement already satisfied: numpy in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ekphrasis) (1.26.4)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in c:\users\hp\appdata\roaming\python\python312\site-packages (from ftfy->ekphrasis) (0.2.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->ekphrasis) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->ekphrasis) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->ekphrasis) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->ekphrasis) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python312\site-packages (from matplotlib->ekphrasis) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->ekphrasis) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->ekphrasis) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\roaming\python\python312\site-packages (from matplotlib->ekphrasis) (2.9.0.post0)
# Requirement already satisfied: click in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nltk->ekphrasis) (8.1.7)
# Requirement already satisfied: joblib in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nltk->ekphrasis) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nltk->ekphrasis) (2023.12.25)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    annotate={"hashtag"},
    fix_html=True, 
    
    segmenter="twitter", 

    corrector="twitter", 
    
    unpack_hashtags=True, 
    unpack_contractions=True, 
    spell_correct_elong=False,

    tokenizer=SocialTokenizer(lowercase=True).tokenize,

    dicts=[emoticons]
)
# Out:
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...

# %%
def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

# %%
def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space_alzami(text):
    return " ".join(text.split())

def remove_emoji_alzami(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") 
    pattern = r"[{}]".format(remove) 
    return re.sub(pattern, "", text)
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:20: SyntaxWarning: invalid escape sequence '\w'
# <>:50: SyntaxWarning: invalid escape sequence '\s'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:20: SyntaxWarning: invalid escape sequence '\w'
# <>:50: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HP\AppData\Local\Temp\ipykernel_8880\3889986115.py:14: SyntaxWarning: invalid escape sequence '\s'
#   return re.sub('\s+',' ',text)
# C:\Users\HP\AppData\Local\Temp\ipykernel_8880\3889986115.py:20: SyntaxWarning: invalid escape sequence '\w'
#   return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
# C:\Users\HP\AppData\Local\Temp\ipykernel_8880\3889986115.py:50: SyntaxWarning: invalid escape sequence '\s'
#   return re.sub('\s+',' ',text)

# %%
def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %%
i = 0
final_string = []
s = ""
for text in df['text'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji_alzami(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space_alzami(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df['step1']=final_string

# %%
df.head(10)
# Out:
#                                                 text  \
# 0  im feeling rather rotten so im not very ambiti...
# 1          im updating my blog because i feel shitty
# 2  i never make her separate from me because i do...
# 3  i left with my bouquet of red and yellow tulip...
# 4    i was feeling a little vain when i did this one
# 5  i cant walk into a shop anywhere where i do no...
# 6   i felt anger when at the end of a telephone call
# 7  i explain why i clung to a relationship with a...
# 8  i like to have the same breathless feeling as ...
# 9  i jest i feel grumpy tired and pre menstrual w...
#
#                                                step1
# 0  im feeling rather rotten so im not very ambiti...
# 1            im updating my blog because feel shitty
# 2  never make her separate from me because don ev...
# 3  left with my bouquet of red and yellow tulips ...
# 4          was feeling little vain when did this one
# 5  cant walk into shop anywhere where do not feel...
# 6       felt anger when at the end of telephone call
# 7  why clung to relationship with boy who was in ...
# 8  like to have the same breathless feeling as re...
# 9  jest feel grumpy tired and pre menstrual which...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2000 non-null   object
#  1   step1   2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB

# %%
df_hapus = df[~df['step1'].str.contains(" ")]

# %%
df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    0 non-null      object
#  1   step1   0 non-null      object
# dtypes: object(2)
# memory usage: 0.0+ bytes

# %%
df_hapus.head(10)
# Out:
# Empty DataFrame
# Columns: [text, step1]
# Index: []

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2000 non-null   object
#  1   step1   2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB

# %%
df_new
# Out:
#                                                    text  \
# 0     im feeling rather rotten so im not very ambiti...
# 1             im updating my blog because i feel shitty
# 2     i never make her separate from me because i do...
# 3     i left with my bouquet of red and yellow tulip...
# 4       i was feeling a little vain when i did this one
# ...                                                 ...
# 1995  i just keep feeling like someone is being unki...
# 1996  im feeling a little cranky negative after this...
# 1997  i feel that i am useful to my people and that ...
# 1998  im feeling more comfortable with derby i feel ...
# 1999  i feel all weird when i have to meet w people ...
#
#                                                   step1
# 0     im feeling rather rotten so im not very ambiti...
# 1               im updating my blog because feel shitty
# 2     never make her separate from me because don ev...
# 3     left with my bouquet of red and yellow tulips ...
# 4             was feeling little vain when did this one
# ...                                                 ...
# 1995  just keep feeling like someone is being unkind...
# 1996  im feeling little cranky negative after this d...
# 1997  feel that am useful to my people and that give...
# 1998  im feeling more comfortable with derby feel as...
# 1999  feel all weird when have to meet people te but...
#
# [2000 rows x 2 columns]

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df['step1'].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#                                                 text  \
# 0  im feeling rather rotten so im not very ambiti...
# 1          im updating my blog because i feel shitty
# 2  i never make her separate from me because i do...
# 3  i left with my bouquet of red and yellow tulip...
# 4    i was feeling a little vain when i did this one
# 5  i cant walk into a shop anywhere where i do no...
# 6   i felt anger when at the end of a telephone call
# 7  i explain why i clung to a relationship with a...
# 8  i like to have the same breathless feeling as ...
# 9  i jest i feel grumpy tired and pre menstrual w...
#
#                                                step1  \
# 0  im feeling rather rotten so im not very ambiti...
# 1            im updating my blog because feel shitty
# 2  never make her separate from me because don ev...
# 3  left with my bouquet of red and yellow tulips ...
# 4          was feeling little vain when did this one
# 5  cant walk into shop anywhere where do not feel...
# 6       felt anger when at the end of telephone call
# 7  why clung to relationship with boy who was in ...
# 8  like to have the same breathless feeling as re...
# 9  jest feel grumpy tired and pre menstrual which...
#
#                                               tokens
# 0  [im, feeling, rather, rotten, so, im, not, ver...
# 1    [im, updating, my, blog, because, feel, shitty]
# 2  [never, make, her, separate, from, me, because...
# 3  [left, with, my, bouquet, of, red, and, yellow...
# 4  [was, feeling, little, vain, when, did, this, ...
# 5  [cant, walk, into, shop, anywhere, where, do, ...
# 6  [felt, anger, when, at, the, end, of, telephon...
# 7  [why, clung, to, relationship, with, boy, who,...
# 8  [like, to, have, the, same, breathless, feelin...
# 9  [jest, feel, grumpy, tired, and, pre, menstrua...

# %%
normalized_word = pd.read_csv('slangs.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8880\2408214049.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] not in normalized_word_dict:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8880\2408214049.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   normalized_word_dict[row[0]] = row[1]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step2"] = final_string_tokens
df_new.head(56)
# Out:
#                                                  text  \
# 0   im feeling rather rotten so im not very ambiti...
# 1           im updating my blog because i feel shitty
# 2   i never make her separate from me because i do...
# 3   i left with my bouquet of red and yellow tulip...
# 4     i was feeling a little vain when i did this one
# 5   i cant walk into a shop anywhere where i do no...
# 6    i felt anger when at the end of a telephone call
# 7   i explain why i clung to a relationship with a...
# 8   i like to have the same breathless feeling as ...
# 28          do feel insecure sometimes but who doesnt
# 29  highly recommend visiting on wednesday if your...
# 30  ive been missing him and feeling so restless a...
# 31  posted on my facebook page earlier this week i...
# 32                            start to feel emotional
# 33                       feel so cold href http irish
# 34  feel like defective or something for not havin...
# 35  feel more virtuous than when eat veggies dippe...
# 36  feel very honoured to be included in magzine w...
# 37  spent the last two weeks of school feeling mis...
# 38  im feeling very peaceful about our wedding aga...
# 39  had been talking to coach claudia barcomb and ...
# 40  feel if completely hated things my democratic ...
# 41  feel humiliated embarrassed or foolish will re...
# 42  feel reassured that am dealing with my diet in...
# 43  feel have to agree with her even though can im...
# 44  im in such happy mood today feel almost deligh...
# 45       im feeling really out of place and irritated
# 46  also know that feel nothing than friendly affe...
# 47  feel like had rather productive weekend and ca...
# 48                  im feeling insecure at the moment
# 49  was feeling pretty an all day but my first day...
# 50  stood up to you finally stood up to you and no...
# 51                  feel little nervous go to the gym
# 52  feel like could go into any situation and beco...
# 53  can stop the an feel when alone when ve got no...
# 54  im trying to feel out my house style now that ...
# 55  have tried to see what it would be like if lik...
#
#                                                tokens  \
# 0   [im, feeling, rather, rotten, so, im, not, ver...
# 1     [im, updating, my, blog, because, feel, shitty]
# 2   [never, make, her, separate, from, me, because...
# 3   [left, with, my, bouquet, of, red, and, yellow...
# 4   [was, feeling, little, vain, when, did, this, ...
# 5   [cant, walk, into, shop, anywhere, where, do, ...
# 6   [felt, anger, when, at, the, end, of, telephon...
# 7   [why, clung, to, relationship, with, boy, who,...
# 8   [like, to, have, the, same, breathless, feelin...
# 9   [jest, feel, grumpy, tired, and, pre, menstrua...
# 10                [don, feel, particularly, agitated]
# 11  [feel, beautifully, emotional, knowing, that, ...
# 12  [pay, attention, it, deepens, into, feeling, o...
# 13  [just, feel, comfortable, with, the, group, of...
# 14  [find, myself, in, the, odd, position, of, fee...
# 15  [was, feeling, as, heartbroken, as, im, sure, ...
# 16                      [feel, little, mellow, today]
# 17  [feel, like, my, only, role, now, would, be, t...
# 18  [feel, just, bcoz, fight, we, get, mad, to, ea...
# 19  [feel, like, reds, and, purples, are, just, so...
# 20  [im, not, sure, the, feeling, of, loss, will, ...
# 21  [feel, like, ive, gotten, to, know, many, of, ...
# 22  [survey, my, own, posts, over, the, last, few,...
# 23  [also, tell, you, in, hopes, that, anyone, who...
# 24  [don, feel, guilty, like, not, going, to, be, ...
# 25  [hate, it, when, feel, fearful, for, absolutel...
# 26     [am, feeling, outraged, it, shows, everywhere]
# 27  [stole, book, from, one, of, my, all, time, fa...
# 28  [do, feel, insecure, sometimes, but, who, doesnt]
# 29  [highly, recommend, visiting, on, wednesday, i...
# 30  [ive, been, missing, him, and, feeling, so, re...
# 31  [posted, on, my, facebook, page, earlier, this...
# 32                       [start, to, feel, emotional]
# 33                [feel, so, cold, href, http, irish]
# 34  [feel, like, defective, or, something, for, no...
# 35  [feel, more, virtuous, than, when, eat, veggie...
# 36  [feel, very, honoured, to, be, included, in, m...
# 37  [spent, the, last, two, weeks, of, school, fee...
# 38  [im, feeling, very, peaceful, about, our, wedd...
# 39  [had, been, talking, to, coach, claudia, barco...
# 40  [feel, if, completely, hated, things, my, demo...
# 41  [feel, humiliated, embarrassed, or, foolish, w...
# 42  [feel, reassured, that, am, dealing, with, my,...
# 43  [feel, have, to, agree, with, her, even, thoug...
# 44  [im, in, such, happy, mood, today, feel, almos...
# 45  [im, feeling, really, out, of, place, and, irr...
# 46  [also, know, that, feel, nothing, than, friend...
# 47  [feel, like, had, rather, productive, weekend,...
# 48           [im, feeling, insecure, at, the, moment]
# 49  [was, feeling, pretty, an, all, day, but, my, ...
# 50  [stood, up, to, you, finally, stood, up, to, y...
# 51          [feel, little, nervous, go, to, the, gym]
# 52  [feel, like, could, go, into, any, situation, ...
# 53  [can, stop, the, an, feel, when, alone, when, ...
# 54  [im, trying, to, feel, out, my, house, style, ...
# 55  [have, tried, to, see, what, it, would, be, li...
#
#                                          final_tokens  \
# 0   [im, feeling, rather, rotten, so, im, not, ver...
# 1     [im, updating, my, blog, because, feel, shitty]
# 2   [never, make, her, separate, from, me, because...
# 3   [left, with, my, bouquet, of, red, and, yellow...
# 4   [was, feeling, little, vain, when, did, this, ...
# 5   [cant, walk, into, shop, anywhere, where, do, ...
# 6   [felt, anger, when, at, the, end, of, telephon...
# 7   [why, clung, to, relationship, with, boy, who,...
# 8   [like, to, have, the, same, breathless, feelin...
# 9   [jest, feel, grumpy, tired, and, pre, menstrua...
# 10                [don, feel, particularly, agitated]
# 11  [feel, beautifully, emotional, knowing, that, ...
# 12  [pay, attention, it, deepens, into, feeling, o...
# 13  [just, feel, comfortable, with, the, group, of...
# 14  [find, myself, in, the, odd, position, of, fee...
# 15  [was, feeling, as, heartbroken, as, im, sure, ...
# 16                      [feel, little, mellow, today]
# 17  [feel, like, my, only, role, now, would, be, t...
# 18  [feel, just, bcoz, fight, we, get, mad, to, ea...
# 19  [feel, like, reds, and, purples, are, just, so...
# 20  [im, not, sure, the, feeling, of, loss, will, ...
# 21  [feel, like, ive, gotten, to, know, many, of, ...
# 22  [survey, my, own, posts, over, the, last, few,...
# 23  [also, tell, you, in, hopes, that, anyone, who...
# 24  [don, feel, guilty, like, not, going, to, be, ...
# 25  [hate, it, when, feel, fearful, for, absolutel...
# 26     [am, feeling, outraged, it, shows, everywhere]
# 27  [stole, book, from, one, of, my, all, time, fa...
# 28  [do, feel, insecure, sometimes, but, who, doesnt]
# 29  [highly, recommend, visiting, on, wednesday, i...
# 30  [ive, been, missing, him, and, feeling, so, re...
# 31  [posted, on, my, facebook, page, earlier, this...
# 32                       [start, to, feel, emotional]
# 33                [feel, so, cold, href, http, irish]
# 34  [feel, like, defective, or, something, for, no...
# 35  [feel, more, virtuous, than, when, eat, veggie...
# 36  [feel, very, honoured, to, be, included, in, m...
# 37  [spent, the, last, two, weeks, of, school, fee...
# 38  [im, feeling, very, peaceful, about, our, wedd...
# 39  [had, been, talking, to, coach, claudia, barco...
# 40  [feel, if, completely, hated, things, my, demo...
